# %%
bool1 = True
print(type(bool1))
# Out:
# <class 'bool'>

# %%
str1 = 'Halo World'
print(type(str1))

# %%
int1 = 1
print(type(int1))

# %%
flt1 = 1.5
print(type(flt1))

# %%
my_list = [1, 2, 3]
print(type(my_list))
print(my_list)
my_list.append(4)
print(my_list)
my_list.pop(2)
print(my_list)
# Out:
# <class 'list'>
# [1, 2, 3]
# [1, 2, 3, 4]
# [1, 2, 4]

# %%
import numpy as np
my_list1 = np.array([2, 4, 6])
print(type(my_list1))
print(my_list1/2)
# Out:
# <class 'numpy.ndarray'>
# [1. 2. 3.]

# %%
tuple1 = (1, 2, 3)
print(type(tuple1))

# %%
my_dict = {
    'Nama':'Rapli', 
    'NIM': '1301204052',
    'Nilai': {'Mtk': '90', 'B_Indo': '100'}
    }
print(type(my_dict))
print(my_dict['Nilai']['Mtk'])
# Out:
# <class 'dict'>
# 90

# %%
num = int(input())
if(num > 0):
  print("Positif")
else:
  print("Negatif")

#Short Hand IF
if(num >0): print("Positif")

#Short Hand IF Else
print("Positif") if(num > 0) else print("Negatif") # Bisa juga tambahin else lagi atau ga elif
# Out:
# -2
# Negatif
# Negatif

# %%
status = True
if Test:
  print("He Right")
else:
  print("He False")

# %%
my_list2 = [1, 2, 3]
if 2 in my_list2:
  print("No\'nt")
else:
  print("Yes\'nt")
# Out:
# No'nt

# %%
y = complex(input())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     565         """
# --> 566         parts = [self.recv(flags, copy=copy, track=track)]
#     567         # have first part already, only loop while more to receive
#
# ...
